# %%
**Cell 1 — load data**
```python
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

conn = sqlite3.connect("../data/jobs.db")
df = pd.read_sql_query("SELECT * FROM jobs", conn)
df.head()
```

**Cell 2 — clean the data**
```python
df["tags"] = df["tags"].fillna("")
df["company"] = df["company"].str.strip()
df = df.drop_duplicates(subset=["url"])
print(f"Total unique jobs: {len(df)}")
```

**Cell 3 — top hiring companies**
```python
top_companies = df["company"].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_companies.values, y=top_companies.index)
plt.title("Top 10 Companies Hiring")
plt.xlabel("Number of Postings")
plt.tight_layout()
plt.savefig("../data/top_companies.png")
plt.show()
```

**Cell 4 — most common skills/tags**
```python
all_tags = df["tags"].str.split(", ").explode()
top_tags = all_tags.value_counts().head(15)
plt.figure(figsize=(10,6))
sns.barplot(x=top_tags.values, y=top_tags.index)
plt.title("Most In-Demand Skills/Tags")
plt.xlabel("Frequency")
plt.tight_layout()
plt.savefig("../data/top_skills.png")
plt.show()
```

**Cell 5 — jobs by source**
```python
df["source"].value_counts().plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))
plt.title("Jobs by Source")
plt.ylabel("")
plt.savefig("../data/jobs_by_source.png")
plt.show()
```

**Cell 6 — location breakdown**
```python
top_locations = df["location"].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_locations.values, y=top_locations.index)
plt.title("Top Job Locations")
plt.tight_layout()
plt.savefig("../data/top_locations.png")
plt.show()
# Out:
#   Cell In[1], line 1
#     **Cell 1 — load data**
#              ^
# SyntaxError: invalid character '—' (U+2014)

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

conn = sqlite3.connect("../data/jobs.db")
df = pd.read_sql_query("SELECT * FROM jobs", conn)
df.head()
# Out:
#    id    source                      title  \
# 0   1  RemoteOK           Junior QA Tester
# 1   2  RemoteOK                         QA
# 2   3  RemoteOK          Creative Director
# 3   4  RemoteOK       Social Media Manager
# 4   5  RemoteOK  Content Marketing Manager
#
#                                   company  \
# 0                        Work Force Nexus
# 1                          VDS INNOVATION
# 2                      Bellweather Agency
# 3                      Degy Entertainment
# 4  Planned Parenthood of Greater New York
#
#                                             location  \
# 0
# 1                                  Vijayawada East,
# 2                  New York, New York, United States
# 3  Delray Beach, Delray Beach, Florida, United St...
# 4        New York, New York, New York, United States
#
#                                                 tags  \
# 0                 testing, quality assurance, junior
# 1                                  quality assurance
# 2  part time, hr, medical, exec, design, salesfor...
# 3  part time, hr, medical, exec, design, salesfor...
# 4  exec, design, amazon, customer support, market...
#
#                  date_posted  \
# 0  2026-07-16T20:04:26+00:00
# 1  2026-07-16T15:40:13+00:00
# 2  2026-07-17T14:41:58+00:00
# 3  2026-07-17T14:30:57+00:00
# 4  2026-07-17T01:11:10+00:00
#
#                                                  url
# 0  https://remoteOK.com/remote-jobs/remote-junior...
# 1  https://remoteOK.com/remote-jobs/remote-qa-vds...
# 2  https://remoteOK.com/remote-jobs/remote-creati...
# 3  https://remoteOK.com/remote-jobs/remote-social...
# 4  https://remoteOK.com/remote-jobs/remote-conten...
